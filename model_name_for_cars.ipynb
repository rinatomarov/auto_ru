# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from glob import glob
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input/cardatasets/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
mits_data = pd.read_csv('/kaggle/input/cardatasets/mits_data.csv')
audi_data = pd.read_csv('/kaggle/input/cardatasets/audi_data.csv')
mercedes_data = pd.read_csv('/kaggle/input/cardatasets/mercedes_data.csv')
bmw_data = pd.read_csv('/kaggle/input/cardatasets/bmw_data.csv')
skoda_data = pd.read_csv('/kaggle/input/cardatasets/skoda_data.csv')
volvo_data = pd.read_csv('/kaggle/input/cardatasets/volvo_data.csv')
nissan_data = pd.read_csv('/kaggle/input/cardatasets/nissan_data.csv')
volks_data = pd.read_csv('/kaggle/input/cardatasets/volks_data.csv')
toyota_data = pd.read_csv('/kaggle/input/cardatasets/toyota_data.csv')

# %%
mits_urls = pd.read_csv('../input/carurls/mitsu_urls.csv')
audi_urls = pd.read_csv('/kaggle/input/carurls/audi_urls.csv')
mers_urls = pd.read_csv('/kaggle/input/carurls/mercedes_urls.csv')
bmw_urls  = pd.read_csv('/kaggle/input/carurls/bmw_urls.csv')
skoda_urls = pd.read_csv('/kaggle/input/carurls/skoda_urls.csv')
volvo_urls = pd.read_csv('/kaggle/input/carurls/volvo_urls.csv')
nissan_urls = pd.read_csv('/kaggle/input/carurls/nissan_urls.csv')
volks_urls = pd.read_csv('/kaggle/input/carurls/volks_urls.csv')
toyota_urls = pd.read_csv('/kaggle/input/carurls/toyota_urls.csv')

# %%
columns_drop = ['Unnamed: 0']
mits_urls = mits_urls.drop(columns_drop, axis=1)
audi_urls = audi_urls.drop(columns_drop, axis=1)
mers_urls = mers_urls.drop(columns_drop, axis=1)
bmw_urls  = bmw_urls.drop(columns_drop, axis=1)
skoda_urls= skoda_urls.drop(columns_drop, axis=1)
volvo_urls= volvo_urls.drop(columns_drop, axis=1)
nissan_urls= nissan_urls.drop(columns_drop, axis=1)
volks_urls= volks_urls.drop(columns_drop, axis=1)
toyota_urls= toyota_urls.drop(columns_drop, axis=1)

# %%
mits_data = pd.read_csv('/kaggle/input/cardatasets/mits_data.csv')
audi_data = pd.read_csv('/kaggle/input/cardatasets/audi_data.csv')
mercedes_data = pd.read_csv('/kaggle/input/cardatasets/mercedes_data.csv')
bmw_data = pd.read_csv('/kaggle/input/cardatasets/bmw_data.csv')
skoda_data = pd.read_csv('/kaggle/input/cardatasets/skoda_data.csv')
volvo_data = pd.read_csv('/kaggle/input/cardatasets/volvo_data.csv')
nissan_data = pd.read_csv('/kaggle/input/cardatasets/nissan_data.csv')
volks_data = pd.read_csv('/kaggle/input/cardatasets/volks_data.csv')
toyota_data = pd.read_csv('/kaggle/input/cardatasets/toyota_data.csv')

# %%
len(toyota_urls)

# %%
lst_urls = []
for i in range(len(toyota_urls)):
    lst_urls.append(toyota_urls.iloc[i][0])

# %%
len(lst_urls)

# %%
a = [i.split('/1', 1)[0] for i in lst_urls]

# %%
lst = []
for i in a:
    n = len(i.split('/'))
    lst.append(i.split('/')[n-1].upper())

# %%
toyota_data['model_name'] = pd.DataFrame(lst)

# %%
toyota_data.isna().info()

# %%
mits_data['brand'] = 'MITSUBISHI'
audi_data['brand'] = 'AUDI'
mercedes_data['brand'] = 'MERCEDES'
bmw_data['brand'] = 'BMW'
skoda_data['brand'] = 'SKODA'
volvo_data['brand'] = 'VOLVO'
nissan_data['brand'] = 'NISSAN'
volks_data['brand'] = 'VOLKSWAGEN'
toyota_data['brand'] = 'TOYOTA'

# %%
mits_data

# %%
frames2 = [mits_data, audi_data ,mercedes_data ,bmw_data , skoda_data ,volvo_data, nissan_data, volks_data, toyota_data]

# %%
result2 = pd.concat(frames2, ignore_index=True, sort=False)

# %%
result2

# %%
columns_drop = ['Unnamed: 0']
result2 = result2.drop(columns_drop, axis=1)

# %%
result2.info()

# %%
result2.to_csv('finalparse.csv')

# %%
lst_urls2 = []
for i in range(len(audi_urls)):
    lst_urls2.append(audi_urls.iloc[i][0])

# %%
b = [i.split('/1', 1)[0] for i in lst_urls2]

# %%
lst2 = []
for i in b:
    n = len(i.split('/'))
    lst2.append(i.split('/')[n-1].upper())

# %%
audi_data['model_name'] = pd.DataFrame(lst2)

# %%
audi_data.isna()

# %%
train_cars = pd.read_csv('../input/parsetraincar/train_cars.csv')

# %%
# car = pd.concat(cars, ignore_index=True)
# car.to_csv('train_cars2.csv')

# skoda['brand'] = 'SKODA'
# volvo['brand'] = 'VOLVO'

# columns_drop = ['Unnamed: 0']
# skoda = skoda.drop(columns_drop, axis=1)
# volvo = volvo.drop(columns_drop, axis=1)

# %%
test = pd.read_csv('../input/testdataset/test.csv')

# %%
stock_files = sorted(glob('/kaggle/input/carparse/*_data.csv'))
stock_files

# %%
train = pd.concat((pd.read_csv(file).assign(filename=file) for file in stock_files),ignore_index=True)

# %%
train
